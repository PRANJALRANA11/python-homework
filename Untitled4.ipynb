# %% [raw]
# In Python, custom exceptions are typically created by defining new classes that inherit from the built-in Exception class or one of its subclasses. Using the Exception class as the base class for custom exceptions is not mandatory, but it is highly recommended, and there are several reasons for doing so:
#
# Consistency and Best Practices: The built-in Exception class is the base class for all standard exceptions in Python. By using it as the base class for custom exceptions, you follow established conventions and best practices, making your code more readable and maintainable for other developers familiar with Python.
#
# Compatibility and Interoperability: Inheriting from Exception ensures that your custom exception behaves like other built-in exceptions in Python. This is essential for consistent exception handling across different parts of your codebase and third-party libraries. It ensures compatibility and interoperability in exception handling.
#
# Error Hierarchy and Catching: Python allows you to catch exceptions based on their class hierarchy. If you inherit from Exception, you can catch your custom exception using a generic except Exception block, or you can be more specific by catching just your custom exception. This flexibility makes it easier to handle different types of exceptions separately.
#
# Additional Functionality: By inheriting from Exception, your custom exception can take advantage of all the features and methods provided by the base Exception class and its subclasses. These features can include properties like args to store additional error information and methods like __str__ to customize the exception's string representation.
#
# Future-Proofing: Python's standard library and third-party libraries often expect custom exceptions to be subclasses of Exception. By following this convention, you ensure that your code is compatible with existing and future libraries, which may rely on the base Exception class in their exception handling.

# %%
def print_exception_hierarchy(exception_class, indent=0):
    print(" " * indent + exception_class.__name__)
    for subclass in exception_class.__subclasses__():
        print_exception_hierarchy(subclass, indent + 2)


if __name__ == "__main__":
    print("Python Exception Hierarchy:")
    print_exception_hierarchy(Exception)
# Out:
# Python Exception Hierarchy:
# Exception
#   TypeError
#     FloatOperation
#     MultipartConversionError
#   StopAsyncIteration
#   StopIteration
#   ImportError
#     ModuleNotFoundError
#     ZipImportError
#   OSError
#     ConnectionError
#       BrokenPipeError
#       ConnectionAbortedError
#       ConnectionRefusedError
#       ConnectionResetError
#         RemoteDisconnected
#     BlockingIOError
#     ChildProcessError
#     FileExistsError
#     FileNotFoundError
#     IsADirectoryError
#     NotADirectoryError
#     InterruptedError
#       InterruptedSystemCall
#     PermissionError
#     ProcessLookupError
#     TimeoutError
#     UnsupportedOperation
#     itimer_error
#     herror
#     gaierror
#     SSLError
#       SSLCertVerificationError
#       SSLZeroReturnError
#       SSLWantWriteError
#       SSLWantReadError
#       SSLSyscallError
#       SSLEOFError
#     Error
#       SameFileError
#     SpecialFileError
#     ExecError
#     ReadError
#     URLError
# ...

# %% [raw]
# In Python, the ArithmeticError class is the base class for exceptions that occur during arithmetic operations. It serves as the parent class for several specific arithmetic-related exception classes. Some common errors defined in the ArithmeticError class are:
#
# OverflowError: Raised when an arithmetic operation exceeds the limits of the data type.
#
# ZeroDivisionError: Raised when attempting to divide by zero.

# %% [raw]
# The LookupError class is used as the base class for exceptions that occur when a lookup or indexing operation fails. It serves as the parent class for specific lookup-related exception classes, such as KeyError and IndexError. By using LookupError, you can catch these lookup-related errors more generally and handle them in a unified way.
#
# Now, let's explore the two specific exceptions derived from LookupError: KeyError and IndexError.

# %% [raw]
# ImportError is an exception that occurs when an import statement fails to find and load the module being imported. It can happen for various reasons, such as if the module doesn't exist, if there's an issue with the Python path, or if there are errors in the module's code that prevent it from being imported correctly.
# The main difference between ImportError and ModuleNotFoundError is that the latter provides more specific information about the nature of the error – that is, the module itself was not found. In contrast, an ImportError can be raised for other reasons besides the module not being found.
